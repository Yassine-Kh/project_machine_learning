# %%
import pandas as pd
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import MinMaxScaler

# from sklearn.metrics import plot_roc_curve
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class CleanData():
    
    def __init__(self, file_url):
        self.df = pd.read_csv(file_url)
        
    def __str__(self):
        return "This dataframe looks like this: \n\n{}".format(self.df.head())
    
    def getColumns(self):
        return self.df.columns
    
    def setColumns(self, column_names):
        self.df.columns = column_names
        
    def checkData(self):
        """
        Check if the data contains any null values
        """
        counter=0
        for col_name in self.getColumns:
            if  self.df[col_name].isnull().values.any():
                # print(f"the column {col_name} contains a null value")
                counter+=1
        return counter
    
    def cleanData(self, column_names):
        if any(element.isdigit() for element in self.getColumns()):  ##J'ai cahnge ca !
            self.setColumns(column_names)
        for col_name in self.getColumns():
                if self.df[col_name].isnull().values.any():
                    self.df[col_name] = self.df[col_name].fillna(method= 'bfill')
        if ["id","classification"] in list(self.getColumns()):
            self.df_to_treat= self.df.drop(["id", "classification"], axis=1)    # a quel moment? quel dataframe ?
            return self.df_to_treat
        return self.df
    
    def normalizeData(self, dataframe,  method="minmax"): # We don't want to change directlyy the attribute df because we need it after
        min_max_scaler = MinMaxScaler()
        for col_name in dataframe.columns:
                if is_numeric_dtype(self.df[col_name]):
                    dataframe[col_name] =  min_max_scaler.fit_transform(dataframe[col_name].values.astype(float).reshape(-1, 1))
        return dataframe
    
    def arrangedData(self, test_size, random_state, *column_names):
        self.new_df = self.normalizeData(self.cleanData(column_names[0]))
        X,y = self.new_df, self.df["classification"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
        return X_train, X_test, y_train, y_test

        
data1 = CleanData("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt")
print(data1)
column_names = ["variance", "skewness", "curtosis", "entropy", "classification"]
X_train, X_test, y_train, y_test = data1.arrangedData(1/3, 42, column_names)
# Out:
# This dataframe looks like this:
#
#     3.6216  8.6661  -2.8073  -0.44699  0
# 0  4.54590  8.1674  -2.4586  -1.46210  0
# 1  3.86600 -2.6383   1.9242   0.10645  0
# 2  3.45660  9.5228  -4.0112  -3.59440  0
# 3  0.32924 -4.4552   4.5718  -0.98880  0
# 4  4.36840  9.6718  -3.9606  -3.16250  0
# ['3.6216', '8.6661', '-2.8073', '-0.44699', '0']
#       variance  skewness  curtosis   entropy  classification
# 274   0.755273  0.749748  0.143658  0.744387             0.0
# 323   0.762088  0.563374  0.310755  0.940860             0.0
# 1097  0.377698  0.260396  0.516424  0.883485             1.0
# 409   0.647809  0.532714  0.427910  0.876192             0.0
# 325   0.496219  0.273556  0.587736  0.638915             0.0
# ...        ...       ...       ...       ...             ...
# 1095  0.192934  0.742470  0.252361  0.280186             1.0
# 1130  0.217835  0.036390  0.900597  0.690302             1.0
# 1294  0.151252  0.638870  0.273509  0.645971             1.0
# 860   0.336225  0.461479  0.276279  0.791889             1.0
# 1126  0.337437  0.511421  0.311013  0.880548             1.0
#
# [914 rows x 5 columns]

# %%
# import the data
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt")
#df = pd.read_csv("C:/Users/achraf/Desktop/IMT Atlantique/3A/Intro to ML/Projet-ML/kidney_disease.csv")
# add column names
# df.columns=["variance", "skewness", "curtosis", "entropy", "class"]
df.columns
#df.describe(include = 'all').to_csv(sys.stdout, sep = ' ')
# Out:
#  3.6216 8.6661 -2.8073 -0.44699 0
# count 1371.0 1371.0 1371.0 1371.0 1371.0
# mean 0.4314100457330415 1.9174342680650638 1.400694168409921 -1.1921996757840982 0.4449307075127644
# std 2.842494432726142 5.868358595997962 4.310104779488706 2.1016834271163716 0.49713945848267305
# min -7.0421 -13.7731 -5.2861 -8.5482 0.0
# 25% -1.7747000000000002 -1.7113 -1.55335 -2.417 0.0
# 50% 0.49571 2.3134 0.61663 -0.58665 0.0
# 75% 2.81465 6.8131 3.1816 0.39481 1.0
# max 6.8248 12.9516 17.9274 2.4495 1.0

# %%
# Visualise an example of the data
df.head()
# Out:
#     3.6216  8.6661  -2.8073  -0.44699  0
# 0  4.54590  8.1674  -2.4586  -1.46210  0
# 1  3.86600 -2.6383   1.9242   0.10645  0
# 2  3.45660  9.5228  -4.0112  -3.59440  0
# 3  0.32924 -4.4552   4.5718  -0.98880  0
# 4  4.36840  9.6718  -3.9606  -3.16250  0

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Check if the data contains any null values
counter=0
for col_name in df.columns:
    if  df[col_name].isnull().values.any():
        # print(f"the column {col_name} contains a null value")
        counter+=1
print(counter)
# Out:
# 0

# %%
def clean_data(dataframe):
    if any(ele.isdigit() for ele in dataframe.columns):
        print("entered")
        dataframe.columns=["variance", "skewness", "curtosis", "entropy", "classification"]
    for col_name in dataframe.columns:
            if  dataframe[col_name].isnull().values.any():
               dataframe[col_name] = dataframe[col_name].fillna(method= 'bfill')
                
    return dataframe

# %%
df=clean_data(df)
df
# Out:
# entered
#       variance  skewness  curtosis  entropy  classification
# 0      4.54590   8.16740   -2.4586 -1.46210               0
# 1      3.86600  -2.63830    1.9242  0.10645               0
# 2      3.45660   9.52280   -4.0112 -3.59440               0
# 3      0.32924  -4.45520    4.5718 -0.98880               0
# 4      4.36840   9.67180   -3.9606 -3.16250               0
# ...        ...       ...       ...      ...             ...
# 1366   0.40614   1.34920   -1.4501 -0.55949               1
# 1367  -1.38870  -4.87730    6.4774  0.34179               1
# 1368  -3.75030 -13.45860   17.5932 -2.77710               1
# 1369  -3.56370  -8.38270   12.3930 -1.28230               1
# 1370  -2.54190  -0.65804    2.6842  1.19520               1
#
# [1371 rows x 5 columns]

# %%
df_to_treat= df.drop(["id", "classification"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37608/3101587943.py in <module>
# ----> 1 df_to_treat= df.drop(["id", "classification"], axis=1)
#
# ~\miniconda3\envs\LAB_3.9\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\miniconda3\envs\LAB_3.9\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\miniconda3\envs\LAB_3.9\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\miniconda3\envs\LAB_3.9\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\miniconda3\envs\LAB_3.9\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
def normalize_data(dataframe, method="minmax"):
    min_max_scaler = preprocessing.MinMaxScaler()
    for col_name in dataframe.columns:
            if  is_numeric_dtype(dataframe[col_name]):
               dataframe[col_name] =  min_max_scaler.fit_transform(dataframe[col_name].values.astype(float).reshape(-1, 1))
    return dataframe

# %%
from sklearn import preprocessing
new_df = normalize_data(df)

# %%
# df_min_max= (df-df.min())/(df.max()-df.min())
# df_mean_std = (df-df.mean())/df.std()

# %%
# def normalize_data(dataframe, method="minmax"):

# %%
new_df.head()
# df_mean_std.head()
# Out:
#         age        bp    sg   al   su     rbc        pc         pcc  \
# 0  0.522727  0.230769  0.75  0.2  0.0  normal    normal  notpresent
# 1  0.056818  0.000000  0.75  0.8  0.0  normal    normal  notpresent
# 2  0.681818  0.230769  0.25  0.4  0.6  normal    normal  notpresent
# 3  0.522727  0.153846  0.00  0.8  0.0  normal  abnormal     present
# 4  0.556818  0.230769  0.25  0.4  0.0  normal    normal  notpresent
#
#            ba       bgr  ...      hemo  pcv    wc   rc  htn   dm cad appet  \
# 0  notpresent  0.211538  ...  0.836735   44  7800  5.2  yes  yes  no  good
# 1  notpresent  0.856838  ...  0.557823   38  6000  3.9   no   no  no  good
# 2  notpresent  0.856838  ...  0.442177   31  7500  3.9   no  yes  no  poor
# 3  notpresent  0.202991  ...  0.551020   32  6700  3.9  yes   no  no  poor
# 4  notpresent  0.179487  ...  0.578231   35  7300  4.6   no   no  no  good
#
#     pe  ane
# 0   no   no
# 1   no   no
# 2   no  yes
# 3  yes  yes
# 4   no   no
#
# [5 rows x 24 columns]

# %%
# split the data from the label
X,y = new_df, df["classification"]

# %%
 # seperate train data and test data
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# %%
# Out:
#           age        bp    sg   al   su       rbc        pc         pcc  \
# 209  0.193182  0.153846  0.75  0.0  0.0    normal    normal  notpresent
# 280  0.511364  0.230769  1.00  0.0  0.0    normal    normal  notpresent
# 33   0.659091  0.384615  0.75  0.4  0.0  abnormal  abnormal  notpresent
# 210  0.647727  0.384615  0.50  0.8  0.4    normal    normal  notpresent
# 93   0.806818  0.384615  0.25  0.6  0.4  abnormal  abnormal     present
# ..        ...       ...   ...  ...  ...       ...       ...         ...
# 245  0.522727  0.384615  0.50  0.6  0.0  abnormal    normal  notpresent
# 311  0.613636  0.076923  1.00  0.0  0.0    normal    normal  notpresent
# 145  0.625000  0.307692  0.50  1.0  0.0  abnormal  abnormal  notpresent
# 258  0.454545  0.230769  0.75  0.0  0.0    normal    normal  notpresent
# 177  0.715909  0.230769  0.50  0.4  0.2    normal    normal     present
#
#              ba       bgr  ...      hemo  pcv    wc   rc  htn   dm  cad appet  \
# 209  notpresent  0.497863  ...  0.571429   20  6900  3.9   no   no   no  good
# 280  notpresent  0.151709  ...  0.693878   52  8100  5.2   no   no   no  good
# 33   notpresent  0.252137  ...  0.476190   29  9800  4.9  yes   no   no  poor
# 210  notpresent  0.497863  ...  0.285714   20  9800  3.9  yes  yes  yes  good
# 93   notpresent  0.583333  ...  0.414966   30  7000  3.2  yes  yes  yes  poor
# ..          ...       ...  ...       ...  ...   ...  ...  ...  ...  ...   ...
# 245  notpresent  0.173077  ...  0.217687   19  7200  2.6  yes   no  yes  poor
# 311  notpresent  0.235043  ...  0.721088   45  7500  5.6   no   no   no  good
# 145     present  0.408120  ...  0.333333   24  4200  3.3  yes  yes  yes  poor
# 258  notpresent  0.162393  ...  0.734694   44  8400  5.5   no   no   no  good
# 177  notpresent  0.412393  ...  0.687075   41  9800  3.7   no  yes   no  good
#
#       pe  ane
# 209   no   no
# 280   no   no
# 33    no   no
# 210   no  yes
# 93    no   no
# ..   ...  ...
# 245   no   no
# 311   no   no
# 145  yes  yes
# 258   no   no
# 177   no   no
#
# [134 rows x 24 columns]

# %% [markdown]
# ## Decision Tree Classification

# %%
cvp= ShuffleSplit(1000, train_size=2/3)
n_depths = 10
depths = linspace(1, 10, n_depths)

tab_RMSE_tree = zeros(n_depths)
for i in range(n_depths):
    reg_tree = DecisionTreeClassifier(max_depth=depths[i])
    tab_RMSE_tree[i]  = median(sqrt(-cross_val_score(reg_tree, X_train, y_train, scoring='neg_log_loss', cv=cvp)))
    
# Plot
plot(depths, tab_RMSE_tree)
xlabel('Max depth of the tree', size=20)
ylabel('RMSE', size=20)


# reg_tree = DecisionTreeRegressor(max_depth=4)
# reg_tree.fit(X_train, y_train)
# y_tree = reg_tree.predict(x)
# Out:
# C:\Users\achraf\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-566edd4ff441> in <module>
#       6 for i in range(n_depths):
#       7     reg_tree = DecisionTreeClassifier(max_depth=depths[i])
# ----> 8     tab_RMSE_tree[i]  = median(sqrt(-cross_val_score(reg_tree, X_train, y_train, scoring='neg_log_loss', cv=cvp)))
#       9
#      10 # Plot
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
#     390                                 pre_dispatch=pre_dispatch,
# --> 391                                 error_score=error_score)
#     392     return cv_results['test_score']
#     393
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     230             return_times=True, return_estimator=return_estimator,
#     231             error_score=error_score)
# --> 232         for train, test in cv.split(X, y, groups))
#     233
#     234     zipped_scores = list(zip(*scores))
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
#     132             if issparse(X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'normal'

# %%
# sorted(sklearn.metrics.SCORERS.keys())

# %%
classif_tree = DecisionTreeRegressor(max_depth=3)
classif_tree.fit(X_train, y_train)
y_bin_tree_predic = classif_tree.predict(X_test)
y_bin_tree_predic= (y_bin_tree_predic>0.5)

# %%
# for i in range(2) : 
#     plt.figure()
#     y_pred[i,:] = cls[i].predict(x)
#     ConfusionMatrixDisplay(confusion_matrix= confusion_matrix(y,y_pred[i]),
#                                 display_labels=cls[i].classes_).plot(figsize(8,5))
# for i in range(2) : 
#     plt.figure()
#     y_pred[i,:] = cls[i].predict(x)
#     ConfusionMatrixDisplay(confusion_matrix= confusion_matrix(y,y_pred[i]),
#                                 display_labels=cls[i].classes_).plot(figsize(8,5))
# #Finally plot ROC Curves
# for i in range(2) :
#     plot_roc_curve(cls[i],x,y)

# %%
Result_metric= sum(abs(y_bin_tree_predic- y_test))
print(Result_metric)
# Out:
# 32.0

# %% [markdown]
# ## Neural Network Classifier

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e0d280c2b1d7> in <module>
# ----> 1 clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1).fit(X_train, y_train)
#       2 clf.score(X_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     980         """
#     981         return self._fit(X, y, incremental=(self.warm_start and
# --> 982                                             hasattr(self, "classes_")))
#     983
#     984     @property
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     321                              hidden_layer_sizes)
#     322
# --> 323         X, y = self._validate_input(X, y, incremental)
#     324         n_samples, n_features = X.shape
#     325
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#     917     def _validate_input(self, X, y, incremental):
#     918         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 919                          multi_output=True)
#     920         if y.ndim == 2 and y.shape[1] == 1:
#     921             y = column_or_1d(y, warn=True)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     534         # make sure we actually converted to numeric:
#     535         if dtype_numeric and array.dtype.kind == "O":
# --> 536             array = array.astype(np.float64)
#     537         if not allow_nd and array.ndim >= 3:
#     538             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'normal'

# %%
A=[5,4]
A.sort()
A
# Out:
# [4, 5]
